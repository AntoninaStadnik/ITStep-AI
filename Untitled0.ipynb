# %% [markdown]
# <a href="https://colab.research.google.com/github/AntoninaStadnik/ITStep-AI/blob/superwised_learning/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'John'
age = 34

print(name, age)
# Out:
# John 34
